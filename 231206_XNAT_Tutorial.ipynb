# %%
# !pip install xnat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xnat
#   Downloading xnat-0.5.3-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 KB 3.5 MB/s eta 0:00:00
# Collecting click>=7.0.0
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 KB 11.9 MB/s eta 0:00:00
# Collecting importlib-metadata>=6.8.0
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Collecting isodate>=0.5.4
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil~=2.8.2 in /home/jklee320/.local/lib/python3.10/site-packages (from xnat) (2.8.2)
# Collecting pydicom>=2.3.0
#   Downloading pydicom-2.4.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: requests>=2.10.0 in /home/jklee320/.local/lib/python3.10/site-packages (from xnat) (2.31.0)
# Collecting progressbar2>=3.11.0
#   Downloading progressbar2-4.2.0-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=6.8.0->xnat) (1.0.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from isodate>=0.5.4->xnat) (1.16.0)
# Collecting python-utils>=3.0.0
#   Downloading python_utils-3.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jklee320/.local/lib/python3.10/site-packages (from requests>=2.10.0->xnat) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jklee320/.local/lib/python3.10/site-packages (from requests>=2.10.0->xnat) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jklee320/.local/lib/python3.10/site-packages (from requests>=2.10.0->xnat) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jklee320/.local/lib/python3.10/site-packages (from requests>=2.10.0->xnat) (2023.11.17)
# Requirement already satisfied: typing-extensions>3.10.0.2 in /home/jklee320/.local/lib/python3.10/site-packages (from python-utils>=3.0.0->progressbar2>=3.11.0->xnat) (4.8.0)
# Installing collected packages: python-utils, pydicom, isodate, importlib-metadata, click, progressbar2, xnat
#   WARNING: The script pydicom is installed in '/home/jklee320/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts xnat, xnat_cp_project and xnat_data_integrity-check are installed in '/home/jklee320/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed click-8.1.7 importlib-metadata-7.0.0 isodate-0.6.1 progressbar2-4.2.0 pydicom-2.4.3 python-utils-3.8.1 xnat-0.5.3

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 11.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.46.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 13.3 MB/s eta 0:00:0031m14.2 MB/s eta 0:00:01
# Collecting numpy<2,>=1.21
#   Downloading numpy-1.26.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 8.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/jklee320/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Collecting pillow>=8
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 3.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 KB 2.9 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/jklee320/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
#   WARNING: The script f2py is installed in '/home/jklee320/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/jklee320/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.46.0 kiwisolver-1.4.5 matplotlib-3.8.2 numpy-1.26.2 pillow-10.1.0

# %%
import xnat
import pydicom
from pydicom.data import get_testdata_files
import matplotlib.pyplot as plt
import numpy

# %%
# Connecting to an XNAT instance
session = xnat.connect('http://localhost', user = 'admin')
# Out:
# Please enter the password for user 'admin': ········

# %%
session.projects["20231206"]
# Out:
# <ProjectData Sample RSNA-MICCAI Brain Tumor Radiogenomic Classification (20231206)>

# %%
kaggle_project = session.projects["20231206"]
print("Number of subjects in Dataset: ", len(kaggle_project.subjects))
# Out:
# Number of subjects in Dataset:  26

# %%
for subject in session.projects["20231206"].subjects.values():
    print(subject.label)
# Out:
# 00337
# 00001
# 00335
# 00333
# 00037
# 00135
# 00015
# 00119
# 00079
# 00153
# 00013
# 00323
# 00372
# 00287
# 00080
# 00047
# 00422
# 00129
# 00125
# 00027
# 00384
# 00145
# 00082
# 00381
# 00091
# 00163

# %%
file_object_T2w = session.projects["20231206"].subjects['00337'].experiments['00337'].scans['T2w'].resources['DICOM'].files[0]

# %%
ds = pydicom.dcmread(file_object_T2w.open())
plt.imshow(ds.pixel_array)

# %%
# DICOM Header Metadata
dicom_metadata = ds
dicom_metadata
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.8.498.50799227502500666096742929695773896649
# (0008, 0050) Accession Number                    SH: '00337'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 103e) Series Description                  LO: 'T2w'
# (0010, 0010) Patient's Name                      PN: '00337'
# (0010, 0020) Patient ID                          LO: '00337'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0050) Slice Thickness                     DS: '3.0'
# (0018, 0081) Echo Time                           DS: None
# (0018, 0083) Number of Averages                  DS: '1.0'
# (0018, 0084) Imaging Frequency                   DS: '123.256529'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: '3.0'
# (0018, 0088) Spacing Between Slices              DS: '1.0'
# (0018, 0089) Number of Phase Encoding Steps      IS: '207'
# (0018, 0091) Echo Train Length                   IS: '15'
# (0018, 0093) Percent Sampling                    DS: '100.0'
# (0018, 0094) Percent Phase Field of View         DS: '81.25'
# (0018, 0095) Pixel Bandwidth                     DS: '193.0'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 208, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: '160.0'
# (0018, 1316) SAR                                 DS: '0.56151546670149'
# (0018, 1318) dB/dt                               DS: '0.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.78035318266972511579773644609671505591
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.10058197461345241731950578412168528410
# (0020, 0011) Series Number                       IS: '3'
# (0020, 0013) Instance Number                     IS: '20'
# (0020, 0032) Image Position (Patient)            DS: [-95.30700388876, -154.51006382747, -24.302532196045]
# (0020, 0037) Image Orientation (Patient)         DS: [0.9999984769134, -0.0017453283007, 0, 0.00174532830068, 0.9999984769134, 0]
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '-24.302532196045'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 208
# (0028, 0030) Pixel Spacing                       DS: [0.9375, 0.9375]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: '566.0'
# (0028, 1051) Window Width                        DS: '1296.0'
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (7fe0, 0010) Pixel Data                          OW: Array of 106496 elements

# %% [markdown]
# ---
# - To store the header data of a DICOM file in a pandas dataframe

# %%
type(ds)
# https://stackoverflow.com/questions/56601525/how-to-store-the-header-data-of-a-dicom-file-in-a-pandas-dataframe
# Out:
# pydicom.dataset.FileDataset

# %%
# !pip install pandas
import pandas as pd
import re
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/jklee320/.local/lib/python3.10/site-packages (from pandas) (1.26.2)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 KB 10.8 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 KB 10.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jklee320/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.1.3 pytz-2023.3.post1 tzdata-2023.3

# %%
# ds.values()는 데이터셋의 값들을 가져와 DataFrame으로 변환합니다.
df = pd.DataFrame(ds.values())

# tag 열이 pydicom.tag 형식인지 확인 후 변환 및 'tag' 열 추가
df[0] = df[0].apply(lambda x: pydicom.dataelem.DataElement_from_raw(x) if isinstance(x, pydicom.dataelem.RawDataElement) else x)
df['tag'] = df[0].apply(lambda x: pydicom.tag.Tag(x) if isinstance(x, pydicom.tag.BaseTag) else x)
df['tag'] = df['tag'].astype('str')
pattern = r'\(\w{4},\s*\w{4}\)'  
df['tag'] = df['tag'].apply(lambda x: re.search(pattern, x).group() if re.search(pattern, x) else None)

# 'name' 및 'value' 열 생성
df['name'] = df[0].apply(lambda x: x.name)
df['value'] = df[0].apply(lambda x: x.value)

# 필요한 열만 선택하여 DataFrame 재구성
df = df[['tag', 'name', 'value']]

# 상위 3개 행 출력
df.head(3)
# Out:
#             tag                    name                      value
# 0  (0008, 0005)  Specific Character Set                 ISO_IR 100
# 1  (0008, 0008)              Image Type       [DERIVED, SECONDARY]
# 2  (0008, 0016)           SOP Class UID  1.2.840.10008.5.1.4.1.1.4

# %%
df
# Out:
#              tag                               name  \
# 0   (0008, 0005)             Specific Character Set
# 1   (0008, 0008)                         Image Type
# 2   (0008, 0016)                      SOP Class UID
# 3   (0008, 0018)                   SOP Instance UID
# 4   (0008, 0050)                   Accession Number
# 5   (0008, 0060)                           Modality
# 6   (0008, 103e)                 Series Description
# 7   (0010, 0010)                     Patient's Name
# 8   (0010, 0020)                         Patient ID
# 9   (0018, 0023)                MR Acquisition Type
# 10  (0018, 0050)                    Slice Thickness
# 11  (0018, 0081)                          Echo Time
# 12  (0018, 0083)                 Number of Averages
# 13  (0018, 0084)                  Imaging Frequency
# 14  (0018, 0085)                     Imaged Nucleus
# 15  (0018, 0086)                     Echo Number(s)
# 16  (0018, 0087)            Magnetic Field Strength
# 17  (0018, 0088)             Spacing Between Slices
# 18  (0018, 0089)     Number of Phase Encoding Steps
# 19  (0018, 0091)                  Echo Train Length
# 20  (0018, 0093)                   Percent Sampling
# 21  (0018, 0094)        Percent Phase Field of View
# 22  (0018, 0095)                    Pixel Bandwidth
# 23  (0018, 1310)                 Acquisition Matrix
# 24  (0018, 1312)  In-plane Phase Encoding Direction
# 25  (0018, 1314)                         Flip Angle
# 26  (0018, 1316)                                SAR
# 27  (0018, 1318)                              dB/dt
# 28  (0018, 5100)                   Patient Position
# 29  (0020, 000d)                 Study Instance UID
# 30  (0020, 000e)                Series Instance UID
# 31  (0020, 0011)                      Series Number
# 32  (0020, 0013)                    Instance Number
# 33  (0020, 0032)           Image Position (Patient)
# 34  (0020, 0037)        Image Orientation (Patient)
# 35  (0020, 1040)       Position Reference Indicator
# 36  (0020, 1041)                     Slice Location
# 37  (0028, 0002)                  Samples per Pixel
# 38  (0028, 0004)         Photometric Interpretation
# 39  (0028, 0010)                               Rows
# 40  (0028, 0011)                            Columns
# 41  (0028, 0030)                      Pixel Spacing
# 42  (0028, 0100)                     Bits Allocated
# 43  (0028, 0101)                        Bits Stored
# 44  (0028, 0102)                           High Bit
# 45  (0028, 0103)               Pixel Representation
# 46  (0028, 1050)                      Window Center
# 47  (0028, 1051)                       Window Width
# 48  (0028, 1052)                  Rescale Intercept
# 49  (0028, 1053)                      Rescale Slope
# 50  (0028, 1054)                       Rescale Type
# 51  (7fe0, 0010)                         Pixel Data
#
#                                                 value
# 0                                          ISO_IR 100
# 1                                [DERIVED, SECONDARY]
# 2                           1.2.840.10008.5.1.4.1.1.4
# 3   1.2.826.0.1.3680043.8.498.50799227502500666096...
# 4                                               00337
# 5                                                  MR
# 6                                                 T2w
# 7                                     (0, 0, 3, 3, 7)
# 8                                               00337
# 9                                                  2D
# 10                                                3.0
# 11                                               None
# 12                                                1.0
# 13                                         123.256529
# 14                                                 1H
# 15                                                  1
# 16                                                3.0
# 17                                                1.0
# 18                                                207
# 19                                                 15
# 20                                              100.0
# 21                                              81.25
# 22                                              193.0
# 23                                   [0, 256, 208, 0]
# 24                                                ROW
# 25                                              160.0
# 26                                           0.561515
# 27                                                0.0
# 28                                                HFS
# 29  1.2.826.0.1.3680043.8.498.78035318266972511579...
# 30  1.2.826.0.1.3680043.8.498.10058197461345241731...
# 31                                                  3
# 32                                                 20
# 33  [-95.30700388876, -154.51006382747, -24.302532...
# 34  [0.9999984769134, -0.0017453283007, 0, 0.00174...
# 35
# 36                                         -24.302532
# 37                                                  1
# 38                                        MONOCHROME2
# 39                                                256
# 40                                                208
# 41                                   [0.9375, 0.9375]
# 42                                                 16
# 43                                                 16
# 44                                                 15
# 45                                                  0
# 46                                              566.0
# 47                                             1296.0
# 48                                                0.0
# 49                                                1.0
# 50                                                 US
# 51  b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00...
