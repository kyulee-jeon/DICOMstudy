# %%
# Import modules
import os
import numpy as np
import pandas as pd
import xnat
import pydicom
import matplotlib.pyplot as plt
import re

# %%
# Connect to your XNAT Session URL and XNAT User ID
session = xnat.connect('http://localhost', user = 'admin')
# Out:
# Please enter the password for user 'admin': ········

# %%
rsna_project = session.projects["20231206"]
lidc_project = session.projects["20231211"]

# %% [markdown]
# ## Searching
# - https://xnat.readthedocs.io/_/downloads/en/0.3.26/pdf/

# %%
dir(session.classes)
# Out:
# ['AbstractDemographicData',
#  'AbstractExecutionEnvironment',
#  'AbstractProjectAsset',
#  'AbstractProtocol',
#  'AbstractResource',
#  'AbstractResourceTags',
#  'AbstractStatistics',
#  'AbstractSubjectMetadata',
#  'AccessLog',
#  'ActionType',
#  'AddField',
#  'AddFieldString',
#  'AddIDString',
#  'AdditionalStatisticsDouble',
#  'AdditionalVal',
#  'Algorithm',
#  'AliasString',
#  'BuildData',
#  'BytesIO',
#  'Catalog',
#  'CatalogMetafields',
#  'ChangeInfo',
#  'CommentString',
#  'CompilerString',
#  'ComputationData',
#  'ContentString',
#  'ContrastBolus',
#  'CrScanData',
#  'CrSessionData',
#  'Criteria',
#  'CriteriaSet',
#  'CsvValuesString',
#  'CtQcScanData',
#  'CtScanData',
#  'CtScanDataDcmvalidation',
#  'CtScanDataParameters',
#  'CtScanDataParametersCollimationwidth',
#  'CtScanDataParametersDerivation',
#  'CtScanDataParametersEstimateddosesaving',
#  'CtScanDataParametersFov',
#  'CtScanDataParametersRescale',
#  'CtScanDataParametersVoxelres',
#  'CtSessionData',
#  'DatatypeProtocol',
#  'DcmCatalog',
#  'DcmCatalogDimensions',
#  'DcmCatalogVoxelres',
#  'DcmEntry',
#  'DcmValidationString',
#  'DelayInteger',
#  'DemographicData',
#  'DemographicDataHeight',
#  'DemographicDataWeight',
#  'DerivationString',
#  'DerivedData',
#  'DicomCodedValue',
#  'DicomSeries',
#  'DicomSeriesDimensions',
#  'DicomSeriesImageset',
#  'DicomSeriesVoxelres',
#  'DoseFloat',
#  'Dx3DCraniofacialScanData',
#  'Dx3DCraniofacialSessionData',
#  'DxScanData',
#  'DxSessionData',
#  'EcatValidationString',
#  'EcgScanData',
#  'EcgSessionData',
#  'EegScanData',
#  'EegScanDataChannels',
#  'EegScanDataParameters',
#  'EegScanDataParametersDatarecord',
#  'EegScanDataSoftwarefiltersimpedances',
#  'EegScanDataSoftwarefiltersimpedancesImpedance',
#  'EegSessionData',
#  'EegSessionDataSamplinginterval',
#  'EegSessionDataSamplingrate',
#  'ElementActionType',
#  'ElementSecurity',
#  'ElementSecurityListingActions',
#  'Entry',
#  'EntryMetafields',
#  'EpsScanData',
#  'EpsSessionData',
#  'EsScanData',
#  'EsSessionData',
#  'EstimatedDoseSavingFloat',
#  'EsvScanData',
#  'EsvSessionData',
#  'ExperimentData',
#  'ExperimentDataDelay',
#  'ExperimentDataFields',
#  'ExperimentDataSharing',
#  'FieldDefinitionGroup',
#  'FieldDefinitionGroupFields',
#  'FieldDefinitionGroupFieldsFieldPossiblevalues',
#  'FieldMapping',
#  'FieldMappingSet',
#  'FieldSpecification',
#  'FieldSpecificationString',
#  'FieldString',
#  'FieldType',
#  'FieldTypeContent',
#  'FieldTypeHtmlImage',
#  'FieldTypeHtmlLink',
#  'FieldTypeHtmlLinkProperty',
#  'FieldTypeHtmlLinkPropertyInsertvalue',
#  'FieldTypeHtmlLinkSecurelink',
#  'FieldTypeHtmlLinkSecurelinkSecuritymappingvalue',
#  'FileData',
#  'GenericData',
#  'GmScanData',
#  'GmSessionData',
#  'GmvScanData',
#  'GmvSessionData',
#  'GzipFile',
#  'HTMLCell',
#  'HdScanData',
#  'HdSessionData',
#  'HeightFloat',
#  'History',
#  'ImageAssessorData',
#  'ImageResource',
#  'ImageResourceDimensions',
#  'ImageResourceSeries',
#  'ImageResourceSeriesDimensions',
#  'ImageResourceSeriesVoxelres',
#  'ImageResourceVoxelres',
#  'ImageScanData',
#  'ImageScanDataScanner',
#  'ImageScanDataSharing',
#  'ImageSessionData',
#  'ImageSessionDataPipeline',
#  'ImageSessionDataScanner',
#  'InfoEntry',
#  'IntermediateFloat',
#  'InvestigatorData',
#  'IoScanData',
#  'IoSessionData',
#  'IsotopeString',
#  'Jsonb',
#  'LONGVARCHAR',
#  'LabelString',
#  'LayoutDescription',
#  'LayoutDescriptionCoordinates',
#  'LibraryString',
#  'MegScanData',
#  'MegSessionData',
#  'MetaData',
#  'MetaFieldString',
#  'MgScanData',
#  'MgSessionData',
#  'MrAssessorData',
#  'MrQcScanData',
#  'MrScanData',
#  'MrScanDataDcmvalidation',
#  'MrScanDataParameters',
#  'MrScanDataParametersDiffusion',
#  'MrScanDataParametersFov',
#  'MrScanDataParametersInplanephaseencoding',
#  'MrScanDataParametersMatrix',
#  'MrScanDataParametersVoxelres',
#  'MrSessionData',
#  'MrsScanData',
#  'NewsEntry',
#  'NmScanData',
#  'NmSessionData',
#  'OpScanData',
#  'OpSessionData',
#  'OptScanData',
#  'OptScanDataDcmvalidation',
#  'OptScanDataParameters',
#  'OptScanDataParametersFov',
#  'OptScanDataParametersVoxelres',
#  'OptSessionData',
#  'OtherDicomScanData',
#  'OtherDicomSessionData',
#  'OtherQcScanData',
#  'PVisitData',
#  'PYDICOM_LOADED',
#  'ParameterString',
#  'PathInfo',
#  'PetAssessorData',
#  'PetQcScanData',
#  'PetScanData',
#  'PetScanDataEcatvalidation',
#  'PetScanDataParameters',
#  'PetScanDataParametersDimensions',
#  'PetScanDataParametersFilter',
#  'PetScanDataParametersFrames',
#  'PetScanDataParametersFramesFrame',
#  'PetScanDataParametersOffset',
#  'PetScanDataParametersPixelsize',
#  'PetScanDataParametersResolution',
#  'PetScanDataParametersRfilter',
#  'PetScanDataParametersZfilter',
#  'PetSessionData',
#  'PetSessionDataTracer',
#  'PetSessionDataTracerDose',
#  'PetSessionDataTracerIntermediate',
#  'PetSessionDataTracerIsotope',
#  'PetSessionDataTracerTotalmass',
#  'PetmrSessionData',
#  'PetmrSessionDataTracer',
#  'PetmrSessionDataTracerDose',
#  'PetmrSessionDataTracerIntermediate',
#  'PetmrSessionDataTracerIsotope',
#  'PetmrSessionDataTracerTotalmass',
#  'PipelineData',
#  'PipelineDetails',
#  'PipelineDetailsParameters',
#  'PipelineDetailsParametersParameterValues',
#  'PipelineParameterData',
#  'PipelineParameterDataCsvvalues',
#  'PipelineParameterDataParameter',
#  'PlatformString',
#  'PlexiViewerType',
#  'PlexiViewerTypeViewableitem',
#  'PlexiViewerTypeViewableitemHiRes',
#  'PlexiViewerTypeViewableitemHiResLayer',
#  'PlexiViewerTypeViewableitemHiResLayoutref',
#  'PlexiViewerTypeViewableitemLoRes',
#  'PlexiViewerTypeViewableitemLoResParameter',
#  'PlexiViewerTypeViewableitemSchemalink',
#  'PlexiViewerTypeViewableitemThumbnail',
#  'PlexiViewerTypeViewableitemThumbnailSlice',
#  'PlexiViewerTypeViewableitemUserinterface',
#  'PlexiViewerTypeViewableitemUserinterfaceLinkeddropdown',
#  'PossibleValueString',
#  'PrimaryPasswordString',
#  'PrimarySecurityField',
#  'PrimarySecurityFieldString',
#  'Process',
#  'ProcessStep',
#  'ProcessStepCompiler',
#  'ProcessStepLibrary',
#  'ProcessStepPlatform',
#  'ProcessStepProgram',
#  'ProgramString',
#  'Project',
#  'ProjectData',
#  'ProjectDataAliases',
#  'ProjectDataFields',
#  'ProjectParticipant',
#  'ProjectPipelines',
#  'ProjectPipelinesDescendants',
#  'ProjectPipelinesDescendantsDescendantPipeline',
#  'ProjectPipelinesPipeline',
#  'Property',
#  'PropertyString',
#  'ProtocolData',
#  'ProtocolDataCheck',
#  'ProtocolDataCheckComments',
#  'ProtocolDataCheckConditions',
#  'ProtocolDataScans',
#  'ProtocolDataScansScanCheckComments',
#  'ProtocolDataScansScanCheckConditions',
#  'PublicationResource',
#  'QcAssessmentData',
#  'QcAssessmentDataScans',
#  'QcAssessmentDataScansScanSliceqc',
#  'QcManualAssessorData',
#  'QcScanData',
#  'QcScanDataFields',
#  'QcScanDataRating',
#  'RatingString',
#  'ReconstructedImageData',
#  'RegionResource',
#  'RegionResourceCreator',
#  'RegionResourceSubregionlabels',
#  'RequestsFileLike',
#  'Resource',
#  'ResourceCatalog',
#  'ResourceSeries',
#  'RfScanData',
#  'RfSessionData',
#  'RgScanData',
#  'RgSessionData',
#  'RoiCollectionData',
#  'RoleType',
#  'RtImageScanData',
#  'RtSessionData',
#  'SESSION',
#  'SamplingIntervalFloat',
#  'SamplingRateFloat',
#  'ScScanData',
#  'ScannerString',
#  'SchemaLinkType',
#  'ScidResearchData',
#  'ScidResearchDataAnxietydisorders',
#  'ScidResearchDataEatingdisorders',
#  'ScidResearchDataMooddisorders',
#  'ScidResearchDataMoodepisodes',
#  'ScidResearchDataOptional',
#  'ScidResearchDataPsychoticdisorders',
#  'ScidResearchDataPsychoticsymptoms',
#  'ScidResearchDataSomatoformdisorders',
#  'ScidResearchDataSubstanceusedisorders',
#  'ScreeningAssessment',
#  'ScreeningScanData',
#  'SearchField',
#  'SegScanData',
#  'ShareString',
#  'SideEffectsPittsburghData',
#  'SmScanData',
#  'SmSessionData',
#  'SrScanData',
#  'SrSessionData',
#  'StatisticsData',
#  'StatisticsDataAddfield',
#  'StatisticsDataAdditionalstatistics',
#  'StoredSearch',
#  'StoredSearchAllowedUser',
#  'StoredSearchSortBy',
#  'StudyProtocol',
#  'StudyProtocolAcqconditions',
#  'StudyProtocolImagesessiontypes',
#  'StudyProtocolSubjectgroups',
#  'StudyProtocolSubjectvariables',
#  'SubQueryField',
#  'SubQueryFieldMappingcolumns',
#  'SubjectAssessorData',
#  'SubjectData',
#  'SubjectDataAddid',
#  'SubjectDataFields',
#  'SubjectMetadata',
#  'SubjectVariablesData',
#  'SubjectVariablesDataVariables',
#  'TagString',
#  'TarFile',
#  'TotalMassFloat',
#  'Updrs3Data',
#  'Updrs3DataActionposturaltremor',
#  'Updrs3DataClicker',
#  'Updrs3DataFingertaps',
#  'Updrs3DataFoottaps',
#  'Updrs3DataHandmovementsgrip',
#  'Updrs3DataHandsram',
#  'Updrs3DataRigidity',
#  'Updrs3DataTremorrest',
#  'UsScanData',
#  'UsSessionData',
#  'User',
#  'UserGroup',
#  'UserLogin',
#  'UserPrimaryPassword',
#  'ValidationData',
#  'VariableString',
#  'VoiceAudioScanData',
#  'VolumetricRegion',
#  'VolumetricRegionSubregions',
#  'WeightFloat',
#  'WorkflowData',
#  'XNATListing',
#  'XNATNestedObject',
#  'XNATNestedObjectMixin',
#  'XNATObject',
#  'XNATObjectMixin',
#  'XNATSimpleListing',
#  'XNATSubListing',
#  'XNATSubObject',
#  'XNATSubObjectMixin',
#  'XNAT_CLASS_LOOKUP',
#  'Xa3DScanData',
#  'Xa3DSessionData',
#  'XaScanData',
#  'XaScanDataParameters',
#  'XaScanDataParametersFov',
#  'XaScanDataParametersPixelres',
#  'XaSessionData',
#  'XcScanData',
#  'XcSessionData',
#  'XcvScanData',
#  'XcvSessionData',
#  'XnatExecutionEnvironment',
#  'XnatExecutionEnvironmentParameterfile',
#  'XnatExecutionEnvironmentParameters',
#  'YbocsData',
#  'YgtssData',
#  'YgtssDataMotor',
#  'YgtssDataPhonic',
#  'ZipFile',
#  '_SOURCE_CODE_FILE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'absolute_import',
#  'caching',
#  'current_session',
#  'mixedproperty',
#  'mixin',
#  'os',
#  'pydicom',
#  'search',
#  'tempfile',
#  'unicode_literals']

# %% [markdown]
# ### Accessing DICOM headers of scan

# %% [markdown]
# `session.service.dicom_dump(scan_uri)` 사용하면 되는데, scan_uri는 어떻게 한번에 뽑지?
# - `ScanData.dicom_dump(fields=None)` 에서, fields to filter for DICOM tags, it can either a tag name or tag number. returns JSON object (dict) representation of header

# %% [markdown]
# #### pydicom
# - A limitation of the dicom_dump of XNAT is that field values are truncated under 64 characters.
# - If you want to access
# the entire dicom header, a convenience method is added that reads the header vi `pydicom`

# %%
def scanframe(project_name, subject_name, experiment_name, scan_name): 
    # ID or Accession number
    scan = session.projects[project_name].subjects[subject_name].experiments[experiment_name].scans[scan_name]
    header = scan.read_dicom()
    
    df = pd.DataFrame(header.values())

    df[0] = df[0].apply(lambda x: pydicom.dataelem.DataElement_from_raw(x) if isinstance(x, pydicom.dataelem.RawDataElement) else x)
    df['tag'] = df[0].apply(lambda x: pydicom.tag.Tag(x) if isinstance(x, pydicom.tag.BaseTag) else x)
    df['tag'] = df['tag'].astype('str')
    pattern = r'\(\w{4},\s*\w{4}\)'  
    df['tag'] = df['tag'].apply(lambda x: re.search(pattern, x).group() if re.search(pattern, x) else None)
    
    df['name'] = df[0].apply(lambda x: x.name)
    df['value'] = df[0].apply(lambda x: x.value)
    
    df = df[['tag', 'name', 'value']]

    return df

# %%
# example
scanframe('20231206', '00337', '00337', 'T2w')
# Out:
#              tag                               name  \
# 0   (0008, 0005)             Specific Character Set
# 1   (0008, 0008)                         Image Type
# 2   (0008, 0016)                      SOP Class UID
# 3   (0008, 0018)                   SOP Instance UID
# 4   (0008, 0050)                   Accession Number
# 5   (0008, 0060)                           Modality
# 6   (0008, 103e)                 Series Description
# 7   (0010, 0010)                     Patient's Name
# 8   (0010, 0020)                         Patient ID
# 9   (0018, 0023)                MR Acquisition Type
# 10  (0018, 0050)                    Slice Thickness
# 11  (0018, 0081)                          Echo Time
# 12  (0018, 0083)                 Number of Averages
# 13  (0018, 0084)                  Imaging Frequency
# 14  (0018, 0085)                     Imaged Nucleus
# 15  (0018, 0086)                     Echo Number(s)
# 16  (0018, 0087)            Magnetic Field Strength
# 17  (0018, 0088)             Spacing Between Slices
# 18  (0018, 0089)     Number of Phase Encoding Steps
# 19  (0018, 0091)                  Echo Train Length
# 20  (0018, 0093)                   Percent Sampling
# 21  (0018, 0094)        Percent Phase Field of View
# 22  (0018, 0095)                    Pixel Bandwidth
# 23  (0018, 1310)                 Acquisition Matrix
# 24  (0018, 1312)  In-plane Phase Encoding Direction
# 25  (0018, 1314)                         Flip Angle
# 26  (0018, 1316)                                SAR
# 27  (0018, 1318)                              dB/dt
# 28  (0018, 5100)                   Patient Position
# 29  (0020, 000d)                 Study Instance UID
# 30  (0020, 000e)                Series Instance UID
# 31  (0020, 0011)                      Series Number
# 32  (0020, 0013)                    Instance Number
# 33  (0020, 0032)           Image Position (Patient)
# 34  (0020, 0037)        Image Orientation (Patient)
# 35  (0020, 1040)       Position Reference Indicator
# 36  (0020, 1041)                     Slice Location
# 37  (0028, 0002)                  Samples per Pixel
# 38  (0028, 0004)         Photometric Interpretation
# 39  (0028, 0010)                               Rows
# 40  (0028, 0011)                            Columns
# 41  (0028, 0030)                      Pixel Spacing
# 42  (0028, 0100)                     Bits Allocated
# 43  (0028, 0101)                        Bits Stored
# 44  (0028, 0102)                           High Bit
# 45  (0028, 0103)               Pixel Representation
# 46  (0028, 1050)                      Window Center
# 47  (0028, 1051)                       Window Width
# 48  (0028, 1052)                  Rescale Intercept
# 49  (0028, 1053)                      Rescale Slope
# 50  (0028, 1054)                       Rescale Type
#
#                                                 value
# 0                                          ISO_IR 100
# 1                                [DERIVED, SECONDARY]
# 2                           1.2.840.10008.5.1.4.1.1.4
# 3   1.2.826.0.1.3680043.8.498.42164575998861237205...
# 4                                               00337
# 5                                                  MR
# 6                                                 T2w
# 7                                     (0, 0, 3, 3, 7)
# 8                                               00337
# 9                                                  2D
# 10                                                3.0
# 11                                               None
# 12                                                1.0
# 13                                         123.256529
# 14                                                 1H
# 15                                                  1
# 16                                                3.0
# 17                                                1.0
# 18                                                207
# 19                                                 15
# 20                                              100.0
# 21                                              81.25
# 22                                              193.0
# 23                                   [0, 256, 208, 0]
# 24                                                ROW
# 25                                              160.0
# 26                                           0.561515
# 27                                                0.0
# 28                                                HFS
# 29  1.2.826.0.1.3680043.8.498.78035318266972511579...
# 30  1.2.826.0.1.3680043.8.498.10058197461345241731...
# 31                                                  3
# 32                                                  1
# 33  [-95.30700388876, -154.51006382747, -81.302528...
# 34  [0.9999984769134, -0.0017453283007, 0, 0.00174...
# 35
# 36                                         -81.302528
# 37                                                  1
# 38                                        MONOCHROME2
# 39                                                256
# 40                                                208
# 41                                   [0.9375, 0.9375]
# 42                                                 16
# 43                                                 16
# 44                                                 15
# 45                                                  0
# 46                                              566.0
# 47                                             1296.0
# 48                                                0.0
# 49                                                1.0
# 50                                                 US

# %% [markdown]
# ### Extract the ID or Accession # of Projects/ Subjects/ Experiments/ Scans
